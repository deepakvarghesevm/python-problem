# %% [markdown]
# <a href="https://colab.research.google.com/github/deepakvarghesevm/python-problem/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
# Out:
#   File "/tmp/ipykernel_2757/1726759132.py", line 2
#     stu1:{}
#         ^
# SyntaxError: invalid syntax

# %%
from genericpath import exists

studentss=[]
def value(name,mark1):
  name=input("enter the name")
  mark1=input("enter the mark")
  mark={"name":{name},
      'mark':{mark1}}
  marking.append(mark)

  choice=int(input())
while choice=input():
  choice==exists
  break
  if choice==1:
    value
# Out:
#   File "/tmp/ipykernel_2757/663990031.py", line 13
#     choice==exists:
#                   ^
# SyntaxError: invalid syntax

# %%
# !git --version
# Out:
# git version 2.34.1
